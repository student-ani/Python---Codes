# %% [markdown]
# MY DATA MY STORY

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10488\265554930.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("C:/Users/hp/Downloads/3rd Sem/CAP776/daily_screen_time.csv")
df
# Out:
#                    Date  Screen Time (hours)  Phone Lock/Unlock Events  \
# 0   2024-09-25 14:55:03                 4.94                        14
# 1   2024-09-26 14:55:03                 6.07                        13
# 2   2024-09-27 14:55:03                 2.65                         8
# 3   2024-09-28 14:55:03                 4.71                         8
# 4   2024-09-29 14:55:03                 3.13                        16
# 5   2024-09-30 14:55:03                 5.36                         5
# 6   2024-10-01 14:55:03                 5.11                         5
# 7   2024-10-02 14:55:03                 3.97                        14
# 8   2024-10-03 14:55:03                 6.57                        20
# 9   2024-10-04 14:55:03                 4.20                         7
# 10  2024-10-05 14:55:03                 7.84                        19
# 11  2024-10-06 14:55:03                 4.42                        11
# ...

# %%
df.head()
# Out:
#                   Date  Screen Time (hours)  Phone Lock/Unlock Events  \
# 0  2024-09-25 14:55:03                 4.94                        14
# 1  2024-09-26 14:55:03                 6.07                        13
# 2  2024-09-27 14:55:03                 2.65                         8
# 3  2024-09-28 14:55:03                 4.71                         8
# 4  2024-09-29 14:55:03                 3.13                        16
#
#    WhatsApp Usage (times)  Instagram Usage (times)  Facebook Usage (times)  \
# 0                       1                        0                       2
# 1                       4                        2                       5
# 2                       4                        3                       8
# 3                       1                        8                       7
# 4                       1                        1                       6
#
#    YouTube Usage (times)  Email Usage (times)  Chrome Usage (times)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      30 non-null     object
#  1   Screen Time (hours)       30 non-null     float64
#  2   Phone Lock/Unlock Events  30 non-null     int64
#  3   WhatsApp Usage (times)    30 non-null     int64
#  4   Instagram Usage (times)   30 non-null     int64
#  5   Facebook Usage (times)    30 non-null     int64
#  6   YouTube Usage (times)     30 non-null     int64
#  7   Email Usage (times)       30 non-null     int64
#  8   Chrome Usage (times)      30 non-null     int64
#  9   Games Usage (times)       30 non-null     int64
#  10  Others Usage (times)      30 non-null     int64
# dtypes: float64(1), int64(9), object(1)
# memory usage: 2.7+ KB

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Screen Time (hours)'], marker='o', color='b', label='Screen Time (hours)')
plt.fill_between(df['Date'], df['Screen Time (hours)'], color='lightblue', alpha=0.3)
plt.title('Daily Screen Time Over 30 Days')
plt.xlabel('Date')
plt.ylabel('Screen Time (hours)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()

# %%
# Plot App Usage and Lock/Unlock Events
plt.figure(figsize=(10, 6))

# List of apps in your dataset
apps = ['WhatsApp Usage (times)', 'Instagram Usage (times)', 'Facebook Usage (times)', 
        'YouTube Usage (times)', 'Email Usage (times)', 'Chrome Usage (times)', 
        'Games Usage (times)', 'Others Usage (times)']

# Plot each app usage on the same graph
for app in apps:
    plt.plot(df['Date'], df[app], marker='o', label=app)

# Plot lock/unlock events
plt.plot(df['Date'], df['Phone Lock/Unlock Events'], marker='x', linestyle='--', color='red', label='Lock/Unlock Events')

plt.title('App Usage and Phone Lock/Unlock Events Over 30 Days')
plt.xlabel('Date')
plt.ylabel('Usage Count')
plt.xticks(rotation=45)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.tight_layout()
plt.show()
