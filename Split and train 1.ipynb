# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# Load the dataset
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Mileage  Age  Sell Price
# 0    69000    6       18000
# 1    35000    3       34000
# 2    57000    5       26100
# 3    22500    2       40000
# 4    46000    4       31500

# %%
plt.scatter(df['Mileage'], df['Sell Price'])

# %%
plt.scatter(df['Mileage'], df['Sell Price'])

# %%
X=df[['Mileage', 'Age']]
y=df['Sell Price']

cl
#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=10)

# %%
len(X_train)
# Out:
# 16

# %%
X_train
# Out:
#     Mileage  Age
# 0     69000    6
# 10    83000    7
# 12    59000    5
# 3     22500    2
# 15    25400    3
# 6     52000    5
# 16    28000    2
# 14    82450    7
# 1     35000    3
# 2     57000    5
# 5     59000    5
# 19    52000    5
# 18    87600    8
# 17    69000    5
# 8     91000    8
# 7     72000    6

# %%
len(X_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
cl=LinearRegression()

# %%
cl.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
cl.predict(X_test)
# Out:
# array([22322.48183184, 24986.69251552, 17897.39623913, 29996.61489906])

# %%
y_test
# Out:
# 9     22000
# 13    27500
# 11    19500
# 4     31500
# Name: Sell Price, dtype: int64

# %%
cl.score(X_test,y_test )
# Out:
# 0.8717124491005734
