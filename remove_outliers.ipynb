# %%
import pandas as pd
df = pd.read_csv("C:/Users/hp/Downloads/My_Work/outliers_data.csv")
print(df)
# Out:
#       Name  Age   Salary   Department
# 0    Alice   25    50000           HR
# 1      Bob   30  1200000  Engineering
# 2  Charlie   35    70000  Engineering
# 3    David   50    60000           HR
# 4      Eve   28    80000           HR
# 5    Frank   40    55000        Sales
# 6    Grace   50    85000        Sales
# 7     Hank   60    90000        Sales
# 8      Ivy   32  1500000  Engineering
# 9     Jack   45    62000  Engineering

# %% [markdown]
# Visualizing Outliers using Boxplots

# %%
import matplotlib.pyplot as plt
#Boxplot to visualize outliers in the age columns
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.boxplot(df['Age'].dropna())
plt.title('Boxplot of Age: ')

#Boxplot to visualize outliers in the Salary Columns
plt.subplot(1,2,2)
plt.boxplot(df['Salary'].dropna())
plt.title('Boxplot of Salary')
# Out:
# Text(0.5, 1.0, 'Boxplot of Salary')
