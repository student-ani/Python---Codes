# %%
import pandas as pd
data = {
    'Name' : ['Alice','Bob','Charlie'],
    'Age' : [18,20,22],
    'City' : ['NewYork','Los Angeles','Chicago']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   18      NewYork
# 1      Bob   20  Los Angeles
# 2  Charlie   22      Chicago

# %%
df = pd.read_csv('C:/Users/hp/Downloads/CAP450/election_results_2024.csv')
print(df)
# Out:
#          Constituency  Const. No.         Leading Candidate  \
# 0               AJMER          13       BHAGIRATH CHOUDHARY
# 1               ALWAR           8           BHUPENDER YADAV
# 2              AMBALA           1            VARUN CHAUDHRY
# 3    ANANTNAG-RAJOURI           3          MIAN ALTAF AHMAD
# 4           ARAKKONAM           7         S JAGATHRATCHAKAN
# ..                ...         ...                       ...
# 538            Wardha           8       AMAR SHARADRAO KALE
# 539           Wayanad           4              RAHUL GANDHI
# 540        West Delhi           6        KAMALJEET SEHRAWAT
# 541  Yavatmal- Washim          14  SANJAY UTTAMRAO DESHMUKH
# 542         Zahirabad           5      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 0                              Bharatiya Janata Party
# 1                              Bharatiya Janata Party
# 2                            Indian National Congress
# ...

# %%
df.head()  # by default top 5 rows
#df.head(n)  # for top n rows
# Out:
#        Constituency  Const. No.    Leading Candidate  \
# 0             AJMER          13  BHAGIRATH CHOUDHARY
# 1             ALWAR           8      BHUPENDER YADAV
# 2            AMBALA           1       VARUN CHAUDHRY
# 3  ANANTNAG-RAJOURI           3     MIAN ALTAF AHMAD
# 4         ARAKKONAM           7    S JAGATHRATCHAKAN
#
#                          Leading Party    Trailing Candidate  \
# 0               Bharatiya Janata Party  RAMCHANDRA CHOUDHARY
# 1               Bharatiya Janata Party           LALIT YADAV
# 2             Indian National Congress         BANTO KATARIA
# 3  Jammu & Kashmir National Conference        MEHBOOBA MUFTI
# 4            Dravida Munnetra Kazhagam             L VIJAYAN
#
#                              Trailing Party  Margin           Status
# 0                  Indian National Congress  329991  Result Declared
# 1                  Indian National Congress   48282  Result Declared
# ...

# %%
df.tail() #last 5 rows
#df.tail(n) #last n rows
# Out:
#          Constituency  Const. No.         Leading Candidate  \
# 538            Wardha           8       AMAR SHARADRAO KALE
# 539           Wayanad           4              RAHUL GANDHI
# 540        West Delhi           6        KAMALJEET SEHRAWAT
# 541  Yavatmal- Washim          14  SANJAY UTTAMRAO DESHMUKH
# 542         Zahirabad           5      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 538  Nationalist Congress Party – Sharadchandra Pawar
# 539                          Indian National Congress
# 540                            Bharatiya Janata Party
# 541             Shiv Sena (Uddhav Balasaheb Thackrey)
# 542                          Indian National Congress
#
#                     Trailing Candidate            Trailing Party  Margin  \
# 538           RAMDAS CHANDRABHAN TADAS    Bharatiya Janata Party   81648
# 539                         ANNIE RAJA  Communist Party of India  364422
# ...

# %%
df.info()  #get more info. about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Constituency        543 non-null    object
#  1   Const. No.          543 non-null    int64
#  2   Leading Candidate   543 non-null    object
#  3   Leading Party       543 non-null    object
#  4   Trailing Candidate  542 non-null    object
#  5   Trailing Party      542 non-null    object
#  6   Margin              543 non-null    object
#  7   Status              543 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 34.1+ KB

# %%
df.describe()  # descriptive statistics
# Out:
#        Const. No.
# count  543.000000
# mean    18.178637
# std     16.427840
# min      1.000000
# 25%      6.000000
# 50%     14.000000
# 75%     25.000000
# max     80.000000

# %%
print(df['Leading Candidate'])  # select a single column
# Out:
# 0           BHAGIRATH CHOUDHARY
# 1               BHUPENDER YADAV
# 2                VARUN CHAUDHRY
# 3              MIAN ALTAF AHMAD
# 4             S JAGATHRATCHAKAN
#                  ...
# 538         AMAR SHARADRAO KALE
# 539                RAHUL GANDHI
# 540          KAMALJEET SEHRAWAT
# 541    SANJAY UTTAMRAO DESHMUKH
# 542        SURESH KUMAR SHETKAR
# Name: Leading Candidate, Length: 543, dtype: object

# %%
print(df[['Leading Candidate','Leading Party']])  #select multiple columns
# Out:
#             Leading Candidate  \
# 0         BHAGIRATH CHOUDHARY
# 1             BHUPENDER YADAV
# 2              VARUN CHAUDHRY
# 3            MIAN ALTAF AHMAD
# 4           S JAGATHRATCHAKAN
# ..                        ...
# 538       AMAR SHARADRAO KALE
# 539              RAHUL GANDHI
# 540        KAMALJEET SEHRAWAT
# 541  SANJAY UTTAMRAO DESHMUKH
# 542      SURESH KUMAR SHETKAR
#
#                                         Leading Party
# 0                              Bharatiya Janata Party
# 1                              Bharatiya Janata Party
# 2                            Indian National Congress
# 3                 Jammu & Kashmir National Conference
# 4                           Dravida Munnetra Kazhagam
# ..                                                ...
# 538  Nationalist Congress Party – Sharadchandra Pawar
# 539                          Indian National Congress
# 540                            Bharatiya Janata Party
# ...

# %%
# df['Age']=[21,23,19,37]  #for add one more column
# print(df)
# df['Age']=df['Age']+1    #modify in existing column
#print(df)

# %%
df = df.drop(columns=['Const. No.'])  #drop a column
print(df)
# Out:
#          Constituency         Leading Candidate  \
# 0               AJMER       BHAGIRATH CHOUDHARY
# 1               ALWAR           BHUPENDER YADAV
# 2              AMBALA            VARUN CHAUDHRY
# 3    ANANTNAG-RAJOURI          MIAN ALTAF AHMAD
# 4           ARAKKONAM         S JAGATHRATCHAKAN
# ..                ...                       ...
# 538            Wardha       AMAR SHARADRAO KALE
# 539           Wayanad              RAHUL GANDHI
# 540        West Delhi        KAMALJEET SEHRAWAT
# 541  Yavatmal- Washim  SANJAY UTTAMRAO DESHMUKH
# 542         Zahirabad      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 0                              Bharatiya Janata Party
# 1                              Bharatiya Janata Party
# 2                            Indian National Congress
# 3                 Jammu & Kashmir National Conference
# 4                           Dravida Munnetra Kazhagam
# ..                                                ...
# ...

# %%
df = df.drop(index=0)  #drop a row
print(df)
# Out:
#          Constituency         Leading Candidate  \
# 1               ALWAR           BHUPENDER YADAV
# 2              AMBALA            VARUN CHAUDHRY
# 3    ANANTNAG-RAJOURI          MIAN ALTAF AHMAD
# 4           ARAKKONAM         S JAGATHRATCHAKAN
# 5               ARANI        THARANIVENTHAN M S
# ..                ...                       ...
# 538            Wardha       AMAR SHARADRAO KALE
# 539           Wayanad              RAHUL GANDHI
# 540        West Delhi        KAMALJEET SEHRAWAT
# 541  Yavatmal- Washim  SANJAY UTTAMRAO DESHMUKH
# 542         Zahirabad      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 1                              Bharatiya Janata Party
# 2                            Indian National Congress
# 3                 Jammu & Kashmir National Conference
# 4                           Dravida Munnetra Kazhagam
# 5                           Dravida Munnetra Kazhagam
# ..                                                ...
# ...
